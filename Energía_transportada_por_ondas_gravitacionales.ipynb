# %% [markdown]
# <a href="https://colab.research.google.com/github/LuzGarciaP/Curso_Agujeros_Negros/blob/main/Energ%C3%ADa_transportada_por_ondas_gravitacionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **GW150914**
#
# ![prl.png](data:image/png;base64,...)

# %% [markdown]
# ![black hole merge.png](data:image/png;base64,...)

# %% [markdown]
# ![ej1.png](data:image/png;base64,...)

# %%
c = 3.0E8 #m/s
M_sun = 1.99E30 #kg

MBH_1 = 30.0*M_sun
MBH_2 = 35.0*M_sun
MBH_f = 62.0*M_sun

print(MBH_1,MBH_2,MBH_f)
# Out:
# 5.97e+31 6.965e+31 1.2338e+32

# %%
EBH_1 = MBH_1*c*c #J
EBH_2 = MBH_2*c*c
EBH_f = MBH_f*c*c

print(EBH_1,EBH_2,EBH_f)
# Out:
# 5.373e+48 6.2685e+48 1.11042e+49

# %% [markdown]
# Conservación de la energía durante la fusión de los agujeros negros
#
# E$_{BH1}$+E$_{BH2}$=E$_{BHf}$+E$_{GW}$

# %%
EGW = EBH_1 + EBH_2 - EBH_f

print(f"La energía liberada en ondas gravitacionales es " + str(0.001*schw_rad(M_sun)) + " J")
# Out:
# 5.3729999999999905e+47

# %%
rel = EGW/2.0E44
print(f"La energía resultante de la colisión de agujeros negros es " + str(0.001*schw_rad(M_sun)) + "  más potente que la explosión de una supernova")
#print("%.2f" % rel)
# Out:
# 2686.50

# %% [markdown]
# **Longitud de onda**
#
# v = $\lambda \cdot$ f
#
# ![buac20-img-wavecharacteristics.png](data:image/png;base64,...)
#
# Suponiendo una frecuencia de 200 Hz:

# %%
f = 200 #Hz

lon = c/f

print(f"La longitud de onda de esta onda es " + str(0.001*schw_rad(M_sun)) + " m")
# Out:
# 1500000.0
